# %%
maladies_symptomes_1 = {
    "Endométriose": ["douleurs pelviennes", "douleurs pendant les rapports sexuels", "menstruations douloureuses", "infertilité"],
    "Maladie de Charcot": ["faiblesse musculaire", "spasticité", "difficulté à marcher", "problèmes de coordination"],
    "Maladie de Lyme": ["éruption cutanée en forme de cible", "fatigue", "fièvre", "douleurs musculaires et articulaires"],
    "Fibromyalgie": ["douleurs musculaires diffuses", "fatigue chronique", "troubles du sommeil", "troubles cognitifs"],
    "Maladie de Crohn": ["diarrhée", "douleurs abdominales", "fatigue", "perte de poids"],
    "Mononucléose": ["fatigue extrême", "gorge irritée", "ganglions lymphatiques enflés", "fièvre"],
    "Psoriasis": ["plaques de peau épaisses et rouges", "démangeaisons", "plaques argentées sur la peau", "ongles épais ou striés"],
    "Scarlatine": ["éruption cutanée rouge", "gorge irritée", "fièvre", "ganglions lymphatiques enflés"],
    "Hémorroïdes": ["saignements rectaux", "douleurs ou démangeaisons autour de l'anus", "sensation de rectum plein", "saignements pendant les selles"],
    "Schizophrénie": ["hallucinations", "délires", "pensées désorganisées", "troubles cognitifs"],
}

# Affichage du dictionnaire pour les 10 premières maladies
for maladie, symptomes in maladies_symptomes_1.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Endométriose : douleurs pelviennes, douleurs pendant les rapports sexuels, menstruations douloureuses, infertilité
# Maladie de Charcot : faiblesse musculaire, spasticité, difficulté à marcher, problèmes de coordination
# Maladie de Lyme : éruption cutanée en forme de cible, fatigue, fièvre, douleurs musculaires et articulaires
# Fibromyalgie : douleurs musculaires diffuses, fatigue chronique, troubles du sommeil, troubles cognitifs
# Maladie de Crohn : diarrhée, douleurs abdominales, fatigue, perte de poids
# Mononucléose : fatigue extrême, gorge irritée, ganglions lymphatiques enflés, fièvre
# Psoriasis : plaques de peau épaisses et rouges, démangeaisons, plaques argentées sur la peau, ongles épais ou striés
# Scarlatine : éruption cutanée rouge, gorge irritée, fièvre, ganglions lymphatiques enflés
# Hémorroïdes : saignements rectaux, douleurs ou démangeaisons autour de l'anus, sensation de rectum plein, saignements pendant les selles
# ...

# %%
maladies_symptomes_2 = {
    "Zona": ["douleur", "éruption cutanée", "sensibilité cutanée", "démangeaisons", "brûlures"],
    "Embolie pulmonaire": ["essoufflement soudain", "douleur thoracique", "toux avec du sang", "rythme cardiaque rapide", "sueurs"],
    "Sclérose en plaques": ["fatigue", "faiblesse musculaire", "problèmes de coordination", "troubles de la vision", "engourdissements ou picotements"],
    "Appendicite": ["douleur abdominale", "nausées", "vomissements", "fièvre", "perte d'appétit"],
    "Burn-out": ["épuisement professionnel", "détachement émotionnel", "difficulté à se concentrer", "irritabilité", "troubles du sommeil"],
    "Pervers narcissique": ["manipulation", "manque d'empathie", "egotisme", "besoin de contrôle", "violence psychologique"],
    "Rougeole": ["éruption cutanée", "fièvre", "toux", "conjonctivite", "écoulement nasal"],
    "Varicelle": ["éruption cutanée avec des boutons remplis de liquide", "démangeaisons", "fièvre", "fatigue", "maux de tête"],
    "Gale": ["démangeaisons sévères, surtout la nuit", "éruption cutanée en forme de petites bosses rouges", "pustules", "lésions cutanées dues au grattage"],
    "Chlamydia": ["douleur en urinant", "douleur dans le bas-ventre", "écoulement anormal du pénis ou du vagin", "douleur pendant les rapports sexuels", "saignements entre les périodes"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_2.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Zona : douleur, éruption cutanée, sensibilité cutanée, démangeaisons, brûlures
# Embolie pulmonaire : essoufflement soudain, douleur thoracique, toux avec du sang, rythme cardiaque rapide, sueurs
# Sclérose en plaques : fatigue, faiblesse musculaire, problèmes de coordination, troubles de la vision, engourdissements ou picotements
# Appendicite : douleur abdominale, nausées, vomissements, fièvre, perte d'appétit
# Burn-out : épuisement professionnel, détachement émotionnel, difficulté à se concentrer, irritabilité, troubles du sommeil
# Pervers narcissique : manipulation, manque d'empathie, egotisme, besoin de contrôle, violence psychologique
# Rougeole : éruption cutanée, fièvre, toux, conjonctivite, écoulement nasal
# Varicelle : éruption cutanée avec des boutons remplis de liquide, démangeaisons, fièvre, fatigue, maux de tête
# Gale : démangeaisons sévères, surtout la nuit, éruption cutanée en forme de petites bosses rouges, pustules, lésions cutanées dues au grattage
# ...

# %%
maladies_symptomes_3 = {
    "Diarrhée": ["selles liquides ou molles", "crampes abdominales", "ballonnements", "nausées", "vomissements"],
    "Lupus": ["éruptions cutanées en forme de papillon sur le visage", "fatigue", "douleurs articulaires", "fièvre", "perte de cheveux"],
    "Orgelet": ["gonflement de la paupière", "sensibilité à la lumière", "sensation de corps étranger dans l'œil", "écoulement de pus", "douleur"],
    "Phlébite": ["gonflement dans la jambe", "douleur ou sensibilité dans la jambe", "chaleur dans la jambe", "rougeur ou décoloration de la peau", "veines enflées"],
    "Sciatique": ["douleur qui se propage du bas du dos jusqu'à la jambe", "sensation de brûlure ou de picotement le long du nerf sciatique", "faiblesse musculaire", "engourdissement dans la jambe", "difficulté à se tenir debout ou à marcher"],
    "Méningite": ["maux de tête sévères", "raideur du cou", "fièvre", "sensibilité à la lumière", "nausées ou vomissements"],
    "Dépression": ["tristesse persistante", "perte d'intérêt ou de plaisir dans les activités", "fatigue", "changements d'appétit", "troubles du sommeil"],
    "Hernie discale": ["douleur dans le bas du dos", "douleur irradiant dans les fesses et les jambes", "engourdissement ou faiblesse musculaire dans les jambes", "sensation de picotement ou de brûlure dans les bras ou les jambes", "difficulté à se tenir debout ou à marcher"],
    "Hernie hiatale": ["brûlures d'estomac", "régurgitation d'aliments ou de liquides", "sensation de brûlure dans la gorge", "difficulté à avaler", "éructations fréquentes"],
    "AVC": ["engourdissement ou faiblesse du visage, du bras ou de la jambe (souvent d'un côté du corps)", "confusion soudaine", "difficulté à parler ou à comprendre la parole", "maux de tête soudains et intenses", "problèmes de vision soudains"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_3.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Diarrhée : selles liquides ou molles, crampes abdominales, ballonnements, nausées, vomissements
# Lupus : éruptions cutanées en forme de papillon sur le visage, fatigue, douleurs articulaires, fièvre, perte de cheveux
# Orgelet : gonflement de la paupière, sensibilité à la lumière, sensation de corps étranger dans l'œil, écoulement de pus, douleur
# Phlébite : gonflement dans la jambe, douleur ou sensibilité dans la jambe, chaleur dans la jambe, rougeur ou décoloration de la peau, veines enflées
# Sciatique : douleur qui se propage du bas du dos jusqu'à la jambe, sensation de brûlure ou de picotement le long du nerf sciatique, faiblesse musculaire, engourdissement dans la jambe, difficulté à se tenir debout ou à marcher
# Méningite : maux de tête sévères, raideur du cou, fièvre, sensibilité à la lumière, nausées ou vomissements
# Dépression : tristesse persistante, perte d'intérêt ou de plaisir dans les activités, fatigue, changements d'appétit, troubles du sommeil
# ...

# %%
maladies_symptomes_4 = {
    "Acouphènes": ["bourdonnements, sifflements ou cliquetis dans les oreilles", "sensation de pression dans les oreilles", "perte auditive", "vertiges ou étourdissements", "fatigue"],
    "Anémie": ["fatigue", "faiblesse", "pâleur de la peau", "essoufflement", "vertiges ou étourdissements"],
    "Arthrose": ["douleur articulaire", "raideur articulaire", "gonflement des articulations", "crissements ou craquements dans les articulations", "perte de mobilité"],
    "Autisme": ["difficulté à communiquer", "comportements répétitifs", "difficulté à établir des relations sociales", "intérêts restreints", "sensibilité sensorielle"],
    "Conjonctivite": ["rougeur des yeux", "démangeaisons ou brûlures des yeux", "sensation de corps étranger dans les yeux", "écoulement de pus ou de larmes", "sensibilité à la lumière"],
    "Cystite": ["douleur ou sensation de brûlure en urinant", "besoin fréquent et urgent d'uriner", "sang dans l'urine", "urine trouble ou malodorante", "inconfort pelvien"],
    "Diabète": ["soif excessive", "faim excessive", "urination fréquente", "fatigue", "vision floue"],
    "Eczéma": ["peau sèche, rouge et irritée", "démangeaisons intenses", "éruptions cutanées", "croûtes ou squames sur la peau", "sensibilité cutanée"],
    "Grippe": ["fièvre", "frissons", "maux de tête", "fatigue", "courbatures"],
    "Hypothyroïdie": ["fatigue", "prise de poids", "sensibilité au froid", "peau sèche", "perte de cheveux"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_4.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Acouphènes : bourdonnements, sifflements ou cliquetis dans les oreilles, sensation de pression dans les oreilles, perte auditive, vertiges ou étourdissements, fatigue
# Anémie : fatigue, faiblesse, pâleur de la peau, essoufflement, vertiges ou étourdissements
# Arthrose : douleur articulaire, raideur articulaire, gonflement des articulations, crissements ou craquements dans les articulations, perte de mobilité
# Autisme : difficulté à communiquer, comportements répétitifs, difficulté à établir des relations sociales, intérêts restreints, sensibilité sensorielle
# Conjonctivite : rougeur des yeux, démangeaisons ou brûlures des yeux, sensation de corps étranger dans les yeux, écoulement de pus ou de larmes, sensibilité à la lumière
# Cystite : douleur ou sensation de brûlure en urinant, besoin fréquent et urgent d'uriner, sang dans l'urine, urine trouble ou malodorante, inconfort pelvien
# Diabète : soif excessive, faim excessive, urination fréquente, fatigue, vision floue
# ...

# %%
maladies_symptomes_5 = {
    "Lumbago": ["douleur dans le bas du dos", "raideur dans le bas du dos", "difficulté à bouger ou à se lever", "douleur qui irradie dans les fesses ou les jambes", "douleur qui s'aggrave avec le mouvement"],
    "Malaise vagal": ["sensation de faiblesse", "étourdissements", "vision trouble", "sueurs froides", "nausées"],
    "Papillomavirus": ["verrues génitales", "verrues sur d'autres parties du corps", "saignements vaginaux anormaux", "démangeaisons ou brûlures génitales", "douleur pendant les rapports sexuels"],
    "Roséole": ["fièvre soudaine", "éruption cutanée rose ou rouge sur le corps", "irritabilité", "gonflement des ganglions lymphatiques", "perte d'appétit"],
    "Syphilis": ["ulcères génitaux ou anaux", "éruption cutanée sur le corps", "ganglions lymphatiques enflés", "fatigue", "fièvre"],
    "Pancréatite": ["douleur abdominale sévère", "nausées", "vomissements", "fièvre", "augmentation du rythme cardiaque"],
    "Impétigo": ["cloques remplies de liquide sur la peau", "croûtes jaunes ou brunes sur la peau", "démangeaisons", "écoulement de pus", "fièvre"],
    "Bouton de fièvre": ["picotements ou démangeaisons sur les lèvres", "petites ampoules remplies de liquide sur les lèvres", "croûtes sur les lèvres", "douleur ou picotement autour de la bouche", "fièvre"],
    "Hernie inguinale": ["boule dans l'aine", "douleur ou gêne à l'aine, en particulier en se penchant, en toussant ou en soulevant des objets lourds", "gonflement ou bosse dans l'aine", "faiblesse ou pression dans l'aine", "douleur testiculaire ou scrotale chez les hommes"],
    "Angine blanche": ["gorge irritée ou douloureuse", "ganglions lymphatiques enflés dans le cou", "difficulté à avaler", "fièvre", "maux de tête"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_5.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Lumbago : douleur dans le bas du dos, raideur dans le bas du dos, difficulté à bouger ou à se lever, douleur qui irradie dans les fesses ou les jambes, douleur qui s'aggrave avec le mouvement
# Malaise vagal : sensation de faiblesse, étourdissements, vision trouble, sueurs froides, nausées
# Papillomavirus : verrues génitales, verrues sur d'autres parties du corps, saignements vaginaux anormaux, démangeaisons ou brûlures génitales, douleur pendant les rapports sexuels
# Roséole : fièvre soudaine, éruption cutanée rose ou rouge sur le corps, irritabilité, gonflement des ganglions lymphatiques, perte d'appétit
# Syphilis : ulcères génitaux ou anaux, éruption cutanée sur le corps, ganglions lymphatiques enflés, fatigue, fièvre
# Pancréatite : douleur abdominale sévère, nausées, vomissements, fièvre, augmentation du rythme cardiaque
# Impétigo : cloques remplies de liquide sur la peau, croûtes jaunes ou brunes sur la peau, démangeaisons, écoulement de pus, fièvre
# ...

# %%
maladies_symptomes_6 = {
    "Algodystrophie": ["douleur intense et persistante", "gonflement", "raideur", "changements de couleur de la peau", "sensibilité accrue"],
    "Angine": ["gorge irritée ou douloureuse", "difficulté à avaler", "ganglions lymphatiques enflés dans le cou", "fièvre", "maux de tête"],
    "Constipation": ["difficulté à passer les selles", "selles moins fréquentes que d'habitude", "selles dures ou sèches", "sensation de blocage dans l'intestin", "gonflement abdominal"],
    "Cruralgie": ["douleur qui irradie le long du nerf crural", "sensation de brûlure ou de picotement le long de la jambe", "faiblesse musculaire dans la jambe", "engourdissement dans la jambe", "difficulté à marcher ou à se tenir debout"],
    "Hyperthyroïdie": ["perte de poids", "nervosité ou agitation", "transpiration excessive", "fatigue", "intolérance à la chaleur"],
    "Pneumopathie": ["toux", "fièvre", "difficulté à respirer", "douleur thoracique", "fatigue"],
    "Sinusite": ["congestion nasale", "écoulement nasal épais ou jaunâtre", "douleur faciale ou pression", "maux de tête", "toux"],
    "Tachycardie": ["rythme cardiaque rapide", "battements de cœur irréguliers", "sensation de battement de cœur dans la poitrine", "vertiges ou étourdissements", "essoufflement"],
    "Tuberculose": ["toux persistante", "fièvre", "fatigue", "perte de poids", "transpiration nocturne"],
    "Urticaire": ["démangeaisons", "plaques rouges sur la peau", "plaques surélevées semblables à des piqûres d'ortie", "enflure de la peau", "sensation de brûlure ou de picotement"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_6.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Algodystrophie : douleur intense et persistante, gonflement, raideur, changements de couleur de la peau, sensibilité accrue
# Angine : gorge irritée ou douloureuse, difficulté à avaler, ganglions lymphatiques enflés dans le cou, fièvre, maux de tête
# Constipation : difficulté à passer les selles, selles moins fréquentes que d'habitude, selles dures ou sèches, sensation de blocage dans l'intestin, gonflement abdominal
# Cruralgie : douleur qui irradie le long du nerf crural, sensation de brûlure ou de picotement le long de la jambe, faiblesse musculaire dans la jambe, engourdissement dans la jambe, difficulté à marcher ou à se tenir debout
# Hyperthyroïdie : perte de poids, nervosité ou agitation, transpiration excessive, fatigue, intolérance à la chaleur
# Pneumopathie : toux, fièvre, difficulté à respirer, douleur thoracique, fatigue
# Sinusite : congestion nasale, écoulement nasal épais ou jaunâtre, douleur faciale ou pression, maux de tête, toux
# ...

# %%
maladies_symptomes_7 = {
    "Cholestérol": ["aucun symptôme spécifique", "dépôts de graisse sur la peau autour des yeux", "douleurs thoraciques", "essoufflement", "douleur ou engourdissement dans les bras ou les jambes"],
    "Hépatite B": ["fatigue", "jaunissement de la peau et des yeux", "douleurs abdominales", "perte d'appétit", "nausées"],
    "Herpès": ["cloques douloureuses sur les lèvres ou les organes génitaux", "démangeaisons ou brûlures", "douleur ou picotement", "écoulement de liquide des cloques", "croûtes sur les cloques"],
    "Mal de gorge": ["gorge irritée ou douloureuse", "difficulté à avaler", "ganglions lymphatiques enflés dans le cou", "fièvre", "maux de tête"],
    "Apnée du sommeil": ["ronflements forts", "pauses dans la respiration pendant le sommeil", "souffle court pendant le sommeil", "fatigue diurne excessive", "maux de tête matinaux"],
    "Intoxication alimentaire": ["nausées", "vomissements", "diarrhée", "crampes abdominales", "fièvre"],
    "AIT": ["engourdissement soudain ou faiblesse du visage, des bras ou des jambes (souvent d'un côté du corps)", "difficulté soudaine à parler ou à comprendre la parole", "perte soudaine de vision ou vision trouble", "maux de tête soudains et intenses", "étourdissements ou perte d'équilibre"],
    "Bronchite": ["toux persistante avec expectorations épaisses ou colorées", "douleur thoracique", "essoufflement", "fatigue", "fièvre modérée"],
    "Cancer": ["perte de poids inexpliquée", "fatigue", "sang dans les selles ou l'urine", "bosse ou nodule sous la peau", "changements dans un grain de beauté ou une verrue"],
    "Chalazion": ["gonflement de la paupière", "sensibilité à la lumière", "sensation de corps étranger dans l'œil", "rougeur de la paupière", "vision floue"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_7.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Cholestérol : aucun symptôme spécifique, dépôts de graisse sur la peau autour des yeux, douleurs thoraciques, essoufflement, douleur ou engourdissement dans les bras ou les jambes
# Hépatite B : fatigue, jaunissement de la peau et des yeux, douleurs abdominales, perte d'appétit, nausées
# Herpès : cloques douloureuses sur les lèvres ou les organes génitaux, démangeaisons ou brûlures, douleur ou picotement, écoulement de liquide des cloques, croûtes sur les cloques
# Mal de gorge : gorge irritée ou douloureuse, difficulté à avaler, ganglions lymphatiques enflés dans le cou, fièvre, maux de tête
# Apnée du sommeil : ronflements forts, pauses dans la respiration pendant le sommeil, souffle court pendant le sommeil, fatigue diurne excessive, maux de tête matinaux
# Intoxication alimentaire : nausées, vomissements, diarrhée, crampes abdominales, fièvre
# ...

# %%
maladies_symptomes_8 = {
    "Coqueluche": ["toux persistante avec des quintes de toux violentes", "sifflement respiratoire", "vomissements après avoir toussé", "fatigue", "congestion nasale"],
    "Drépanocytose": ["douleurs osseuses", "fatigue", "palpitations cardiaques", "jaunissement de la peau et des yeux", "infections fréquentes"],
    "Erysipèle": ["peau rouge et enflée", "douleur ou sensibilité de la peau", "fièvre", "ganglions lymphatiques enflés", "plaques surélevées ou bulles sur la peau"],
    "Escarre": ["peau rouge ou violacée", "plaques de peau qui ne blanchissent pas sous la pression", "peau chaude ou fraîche au toucher", "douleur ou démangeaisons", "plaies ouvertes ou ulcères"],
    "Furoncle": ["nodule douloureux sous la peau", "rougeur et gonflement autour du nodule", "douleur à la pression", "écoulement de pus", "fièvre"],
    "Glaucome": ["vision floue ou réduite", "halos autour des lumières", "maux de tête", "nausées ou vomissements", "vision de tunnel"],
    "Hallux valgus": ["bosse osseuse sur le côté du pied", "gros orteil pointant vers les autres orteils", "douleur ou sensibilité dans l'articulation du gros orteil", "cors ou callosités", "difficulté à trouver des chaussures adaptées"],
    "Infarctus": ["douleur thoracique ou malaise", "sensation de pression, de plénitude ou de douleur dans la poitrine", "douleur irradiant vers le bras gauche, le dos, la mâchoire ou l'estomac", "essoufflement", "nausées ou vomissements"],
    "Leucémie": ["fatigue excessive", "perte de poids inexpliquée", "fièvre ou sueurs nocturnes", "infections fréquentes", "ecchymoses ou saignements inhabituels"],
    "Mucoviscidose": ["toux persistante avec expectorations épaisses ou colorées", "essoufflement", "infections pulmonaires fréquentes", "problèmes digestifs", "retard de croissance chez les enfants"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_8.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Coqueluche : toux persistante avec des quintes de toux violentes, sifflement respiratoire, vomissements après avoir toussé, fatigue, congestion nasale
# Drépanocytose : douleurs osseuses, fatigue, palpitations cardiaques, jaunissement de la peau et des yeux, infections fréquentes
# Erysipèle : peau rouge et enflée, douleur ou sensibilité de la peau, fièvre, ganglions lymphatiques enflés, plaques surélevées ou bulles sur la peau
# Escarre : peau rouge ou violacée, plaques de peau qui ne blanchissent pas sous la pression, peau chaude ou fraîche au toucher, douleur ou démangeaisons, plaies ouvertes ou ulcères
# Furoncle : nodule douloureux sous la peau, rougeur et gonflement autour du nodule, douleur à la pression, écoulement de pus, fièvre
# Glaucome : vision floue ou réduite, halos autour des lumières, maux de tête, nausées ou vomissements, vision de tunnel
# ...

# %%
maladies_symptomes_9 = {
    "Pneumonie": ["toux avec expectorations épaisses ou colorées", "fièvre", "essoufflement", "douleur thoracique", "fatigue"],
    "Pneumothorax": ["douleur thoracique soudaine et intense", "essoufflement soudain", "respiration rapide", "toux sèche", "coloration bleutée de la peau"],
    "Rhinopharyngite": ["nez qui coule", "mal de gorge", "éternuements", "congestion nasale", "toux"],
    "Septicémie": ["fièvre", "frissons", "respiration rapide", "rythme cardiaque rapide", "confusion mentale"],
    "Sida": ["infections fréquentes", "fatigue", "enflure des ganglions lymphatiques", "perte de poids inexpliquée", "plaies buccales, génitales ou anales"],
    "Tendinite": ["douleur près d'une articulation", "raideur ou sensibilité de l'articulation", "gonflement", "difficulté à bouger l'articulation", "craquements ou crépitements lors des mouvements"],
    "Toxoplasmose": ["ganglions lymphatiques enflés", "fatigue", "maux de tête", "fièvre légère", "douleurs musculaires"],
    "Vitiligo": ["taches blanches sur la peau", "perte de couleur de la peau", "sensibilité accrue au soleil", "changements de couleur des cheveux ou des poils", "perte de couleur de la rétine"],
    "Cancer du poumon": ["toux persistante ou toux avec expectorations sanglantes", "essoufflement", "douleur thoracique", "perte de poids inexpliquée", "fatigue"],
    "Gastro-entérite": ["nausées", "vomissements", "diarrhée", "crampes abdominales", "fièvre"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_9.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Pneumonie : toux avec expectorations épaisses ou colorées, fièvre, essoufflement, douleur thoracique, fatigue
# Pneumothorax : douleur thoracique soudaine et intense, essoufflement soudain, respiration rapide, toux sèche, coloration bleutée de la peau
# Rhinopharyngite : nez qui coule, mal de gorge, éternuements, congestion nasale, toux
# Septicémie : fièvre, frissons, respiration rapide, rythme cardiaque rapide, confusion mentale
# Sida : infections fréquentes, fatigue, enflure des ganglions lymphatiques, perte de poids inexpliquée, plaies buccales, génitales ou anales
# Tendinite : douleur près d'une articulation, raideur ou sensibilité de l'articulation, gonflement, difficulté à bouger l'articulation, craquements ou crépitements lors des mouvements
# Toxoplasmose : ganglions lymphatiques enflés, fatigue, maux de tête, fièvre légère, douleurs musculaires
# ...

# %%
maladies_symptomes_10 = {
    "Cancer du sein": ["bosse ou grosseur dans le sein ou l'aisselle", "changements de taille ou de forme du sein", "écoulement du mamelon", "peau du sein rouge, épaisse ou écailleuse", "douleur dans le sein ou le mamelon"],
    "Cancer de la peau": ["nouvelle croissance cutanée ou tache", "changement dans une tache de peau existante", "saignement ou démangeaisons d'une lésion cutanée", "asymétrie d'une lésion cutanée", "couleur inégale ou modification de la bordure d'une lésion cutanée"],
    "Maladie de Verneuil": ["nodules douloureux sous la peau", "abcès ou furoncles récurrents", "cicatrices ou plaies sur la peau", "douleur ou sensibilité de la peau", "écoulement de pus"],
    "Hépatite C": ["fatigue", "jaunissement de la peau et des yeux", "douleurs abdominales", "perte d'appétit", "nausées"],
    "Ostéoporose": ["perte de taille", "dos voûté", "fractures osseuses fréquentes", "douleur au dos ou aux os", "perte de masse osseuse"],
    "Trachéite": ["toux sèche", "irritation de la gorge", "mal de gorge", "enrouement", "fièvre légère"],
    "Occlusion intestinale": ["douleur abdominale intense et soudaine", "ballonnements", "vomissements", "constipation sévère", "incapacité à passer les selles ou les gaz"],
    "Insuffisance rénale": ["fatigue", "gonflement des jambes, des chevilles ou des pieds", "essoufflement", "diminution de l'appétit", "confusion mentale"],
    "BPCO": ["essoufflement", "toux persistante avec expectorations épaisses ou colorées", "sifflements respiratoires", "fatigue", "infections pulmonaires fréquentes"],
    "Cataracte": ["vision floue, trouble ou nuageuse", "sensibilité accrue à la lumière", "halos autour des lumières", "vision double dans un œil", "difficulté à voir la nuit"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_10.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Cancer du sein : bosse ou grosseur dans le sein ou l'aisselle, changements de taille ou de forme du sein, écoulement du mamelon, peau du sein rouge, épaisse ou écailleuse, douleur dans le sein ou le mamelon
# Cancer de la peau : nouvelle croissance cutanée ou tache, changement dans une tache de peau existante, saignement ou démangeaisons d'une lésion cutanée, asymétrie d'une lésion cutanée, couleur inégale ou modification de la bordure d'une lésion cutanée
# Maladie de Verneuil : nodules douloureux sous la peau, abcès ou furoncles récurrents, cicatrices ou plaies sur la peau, douleur ou sensibilité de la peau, écoulement de pus
# Hépatite C : fatigue, jaunissement de la peau et des yeux, douleurs abdominales, perte d'appétit, nausées
# Ostéoporose : perte de taille, dos voûté, fractures osseuses fréquentes, douleur au dos ou aux os, perte de masse osseuse
# Trachéite : toux sèche, irritation de la gorge, mal de gorge, enrouement, fièvre légère
# ...

# %%
maladies_symptomes_11 = {
    "Fibrome": ["saignements menstruels abondants", "menstruations prolongées", "pression pelvienne ou douleur", "envies fréquentes d'uriner", "douleur pendant les rapports sexuels"],
    "Hypertension": ["maux de tête", "fatigue ou confusion", "vision trouble", "essoufflement", "saignements de nez fréquents"],
    "Laryngite": ["enrouement", "mal de gorge", "toux sèche", "sensation de brûlure dans la gorge", "difficulté à parler"],
    "Lombalgie": ["douleur dans le bas du dos", "raideur dans le bas du dos", "difficulté à bouger ou à se tenir debout", "douleur qui irradie dans les fesses ou les jambes", "douleur qui s'aggrave avec le mouvement"],
    "Mycose": ["démangeaisons ou brûlures génitales", "douleur ou sensation de brûlure pendant les rapports sexuels", "écoulement vaginal anormal", "rougeur ou gonflement des organes génitaux", "plaques blanches sur les organes génitaux"],
    "Paludisme": ["fièvre", "frissons", "maux de tête", "nausées et vomissements", "fatigue"],
    "Phimosis": ["impossibilité de rétracter le prépuce sur le gland du pénis", "douleur ou inconfort pendant l'érection", "gonflement du prépuce", "infections urinaires fréquentes", "saignements ou ulcères sous le prépuce"],
    "Polyarthrite": ["douleur, gonflement et raideur articulaires", "fatigue", "perte d'appétit", "raideur matinale prolongée", "déformation des articulations"],
    "Polype": ["aucun symptôme spécifique", "saignements rectaux", "saignements vaginaux anormaux", "douleur abdominale", "changements dans les habitudes intestinales"],
    "Purpura": ["taches pourpres ou rouges sur la peau", "saignements sous la peau", "saignements des gencives ou du nez", "fatigue", "fièvre"],
}

# Affichage du dictionnaire pour les 10 maladies suivantes
for maladie, symptomes in maladies_symptomes_11.items():
    print(f"{maladie} : {', '.join(symptomes)}")
# Out:
# Fibrome : saignements menstruels abondants, menstruations prolongées, pression pelvienne ou douleur, envies fréquentes d'uriner, douleur pendant les rapports sexuels
# Hypertension : maux de tête, fatigue ou confusion, vision trouble, essoufflement, saignements de nez fréquents
# Laryngite : enrouement, mal de gorge, toux sèche, sensation de brûlure dans la gorge, difficulté à parler
# Lombalgie : douleur dans le bas du dos, raideur dans le bas du dos, difficulté à bouger ou à se tenir debout, douleur qui irradie dans les fesses ou les jambes, douleur qui s'aggrave avec le mouvement
# Mycose : démangeaisons ou brûlures génitales, douleur ou sensation de brûlure pendant les rapports sexuels, écoulement vaginal anormal, rougeur ou gonflement des organes génitaux, plaques blanches sur les organes génitaux
# Paludisme : fièvre, frissons, maux de tête, nausées et vomissements, fatigue
# ...

# %%
# Conversion de l'ensemble de symptômes en une liste
unique_symptoms_list = list(unique_symptoms)

# Création d'un DataFrame avec les symptômes uniques comme colonnes et les maladies comme lignes
df = pd.DataFrame(columns=unique_symptoms_list, index=maladies)

# Remplissage du DataFrame avec des valeurs booléennes
for maladie, symptomes in all_symptoms.items():
    for symptome in symptomes:
        df.loc[maladie, symptome] = 1

# Remplissage des valeurs manquantes avec 0
df = df.fillna(0).astype(int)

# Affichage des 5 premières lignes du DataFrame
print(df.head())
# Out:
#                     frissons  ronflements forts  démangeaisons intenses  \
# Endométriose               0                  0                       0
# Maladie de Charcot         0                  0                       0
# Maladie de Lyme            0                  0                       0
# Fibromyalgie               0                  0                       0
# Maladie de Crohn           0                  0                       0
#
#                     besoin de contrôle  raideur  troubles cognitifs  \
# Endométriose                         0        0                   0
# Maladie de Charcot                   0        0                   0
# Maladie de Lyme                      0        0                   0
# Fibromyalgie                         0        0                   1
# Maladie de Crohn                     0        0                   0
#
#                     fatigue excessive  rougeur de la paupière  soif excessive  \
# ...

# %%
df
# Out:
#                     frissons  ronflements forts  démangeaisons intenses  \
# Endométriose               0                  0                       0
# Maladie de Charcot         0                  0                       0
# Maladie de Lyme            0                  0                       0
# Fibromyalgie               0                  0                       0
# Maladie de Crohn           0                  0                       0
# ...                      ...                ...                     ...
# Polype                     0                  0                       0
# Purpura                    0                  0                       0
# Ulcère                     0                  0                       0
# Ver solitaire              0                  0                       0
# Gastro-entérite            0                  0                       0
#
#                     besoin de contrôle  raideur  troubles cognitifs  \
# ...

# %%
df.to_csv('DB110Maladies.csv')

# %%
import pandas as pd
df= pd.read_csv('DB110Maladies.csv')

# %%
# Récupération des symptômes de la maladie de Charcot
symptomes_charcot = df.loc["Maladie de Charcot"][df.loc["Maladie de Charcot"] == 1]

# Affichage des symptômes de la maladie de Charcot
print("Symptômes de la maladie de Charcot :")
print(symptomes_charcot)
# Out:
# Symptômes de la maladie de Charcot :
# difficulté à marcher         1
# faiblesse musculaire         1
# spasticité                   1
# problèmes de coordination    1
# Name: Maladie de Charcot, dtype: int64

# %%
# Liste des symptômes spécifiques
symptomes_specifiques = ["fièvre", "fatigue", "douleur"]

# Filtrage du DataFrame pour les maladies ayant au moins un des symptômes spécifiques
maladies_avec_symptomes = df[df[symptomes_specifiques].any(axis=1)]

# Affichage des maladies associées aux symptômes spécifiques
print("Maladies associées aux symptômes spécifiques :")
print(maladies_avec_symptomes.index.tolist())
# Out:
# Maladies associées aux symptômes spécifiques :
# ['Maladie de Lyme', 'Maladie de Crohn', 'Mononucléose', 'Scarlatine', 'Zona', 'Sclérose en plaques', 'Appendicite', 'Rougeole', 'Varicelle', 'Lupus', 'Orgelet', 'Méningite', 'Dépression', 'Acouphènes', 'Anémie', 'Diabète', 'Grippe', 'Hypothyroïdie', 'Syphilis', 'Pancréatite', 'Impétigo', 'Bouton de fièvre', 'Angine blanche', 'Angine', 'Hyperthyroïdie', 'Pneumopathie', 'Tuberculose', 'Hépatite B', 'Mal de gorge', 'Intoxication alimentaire', 'Bronchite', 'Cancer', 'Coqueluche', 'Drépanocytose', 'Erysipèle', 'Furoncle', 'Pneumonie', 'Septicémie', 'Sida', 'Toxoplasmose', 'Cancer du poumon', 'Hépatite C', 'Insuffisance rénale', 'BPCO', 'Paludisme', 'Polyarthrite', 'Purpura', 'Gastro-entérite']

# %%
# Liste des symptômes spécifiques
symptomes_specifiques = ["fièvre", "fatigue", "douleur"]

# Filtrage du DataFrame pour les maladies ayant au moins deux des symptômes spécifiques
maladies_avec_symptomes = df[df[symptomes_specifiques].sum(axis=1) >= 2]

# Affichage des maladies associées aux symptômes spécifiques
print("Maladies associées à au moins deux des symptômes spécifiques :")
print(maladies_avec_symptomes.index.tolist())
# Out:
# Maladies associées à au moins deux des symptômes spécifiques :
# ['Maladie de Lyme', 'Varicelle', 'Lupus', 'Grippe', 'Syphilis', 'Pneumopathie', 'Tuberculose', 'Pneumonie', 'Paludisme', 'Purpura']
